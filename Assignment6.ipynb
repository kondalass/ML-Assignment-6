# %%
#Q1- Mathematical Part Solution is provided in Document, the below code is just for reference for Q1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.cluster.hierarchy as shc
from scipy.spatial.distance import squareform, pdist

a = np.array([0.4005,0.2148,0.3457,0.2652,0.0789,0.4548])
b = np.array([0.5306,0.3854,0.3156,0.1875,0.4139,0.3022])

point = ['P1','P2','P3','P4','P5','P6']
data = pd.DataFrame({'Point':point, 'x cordinate':a, 'y cordinate':b})
data = data.set_index('Point')
data
# Out:
#        x cordinate  y cordinate
# Point
# P1          0.4005       0.5306
# P2          0.2148       0.3854
# P3          0.3457       0.3156
# P4          0.2652       0.1875
# P5          0.0789       0.4139
# P6          0.4548       0.3022

# %%
dist = pd.DataFrame(squareform(np.round(pdist(data[['x cordinate', 'y cordinate']]),4), 'euclidean'), columns=data.index.values, index=data.index.values)
dist
# Out:
#         P1      P2      P3      P4      P5      P6
# P1  0.0000  0.2357  0.2219  0.3688  0.3421  0.2348
# P2  0.2357  0.0000  0.1483  0.2042  0.1389  0.2540
# P3  0.2219  0.1483  0.0000  0.1513  0.2843  0.1099
# P4  0.3688  0.2042  0.1513  0.0000  0.2932  0.2216
# P5  0.3421  0.1389  0.2843  0.2932  0.0000  0.3921
# P6  0.2348  0.2540  0.1099  0.2216  0.3921  0.0000

# %%
plt.figure(figsize=(10,4)) 
plt.title("Dendrogram with Single inkage")  
dend = shc.dendrogram(shc.linkage(data[['x cordinate', 'y cordinate']], method='single'), labels=data.index)

# %%
plt.figure(figsize=(10,4)) 
plt.title("Dendrogram with Complete inkage")  
dend = shc.dendrogram(shc.linkage(data[['x cordinate', 'y cordinate']], method='complete'), labels=data.index)

# %%
plt.figure(figsize=(10,4)) 
plt.title("Dendrogram with Average inkage")  
dend = shc.dendrogram(shc.linkage(data[['x cordinate', 'y cordinate']], method='average'), labels=data.index)

# %%
## 2) Use CC_GENERAL.csv given in the folder and apply:
    # a) Preprocess the data by removing the categorical column and filling the missing values.
    # b) Apply StandardScaler() and normalize() functions to scale and normalize raw input data.
    # c) Use PCA with K=2 to reduce the input dimensions to two features.
    # d) Apply Agglomerative Clustering with k=2,3,4 and 5 on reduced features and visualize
    # result for each k value using scatter plot.
    # e) Evaluate different variations using Silhouette Scores and Visualize results with a bar chart.

# %%
#importing all libraries here for assignment
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing,metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score

import warnings
warnings.filterwarnings("ignore")

# %%
dataframe = pd.read_csv('CC GENERAL.csv')
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
dataframe.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
dataframe.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %%
df = dataframe.drop(['CUST_ID'], axis=1)
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
df.isnull().any()
# Out:
# BALANCE                             False
# BALANCE_FREQUENCY                   False
# PURCHASES                           False
# ONEOFF_PURCHASES                    False
# INSTALLMENTS_PURCHASES              False
# CASH_ADVANCE                        False
# PURCHASES_FREQUENCY                 False
# ONEOFF_PURCHASES_FREQUENCY          False
# PURCHASES_INSTALLMENTS_FREQUENCY    False
# CASH_ADVANCE_FREQUENCY              False
# CASH_ADVANCE_TRX                    False
# PURCHASES_TRX                       False
# CREDIT_LIMIT                         True
# PAYMENTS                            False
# MINIMUM_PAYMENTS                     True
# PRC_FULL_PAYMENT                    False
# TENURE                              False
# dtype: bool

# %%
df.fillna(dataframe.mean(), inplace=True)
df.isnull().any()
# Out:
# BALANCE                             False
# BALANCE_FREQUENCY                   False
# PURCHASES                           False
# ONEOFF_PURCHASES                    False
# INSTALLMENTS_PURCHASES              False
# CASH_ADVANCE                        False
# PURCHASES_FREQUENCY                 False
# ONEOFF_PURCHASES_FREQUENCY          False
# PURCHASES_INSTALLMENTS_FREQUENCY    False
# CASH_ADVANCE_FREQUENCY              False
# CASH_ADVANCE_TRX                    False
# PURCHASES_TRX                       False
# CREDIT_LIMIT                        False
# PAYMENTS                            False
# MINIMUM_PAYMENTS                    False
# PRC_FULL_PAYMENT                    False
# TENURE                              False
# dtype: bool

# %%
df.corr().style.background_gradient(cmap="Greens")
# Out:
# <style type="text/css">
# #T_51a96_row0_col0, #T_51a96_row1_col1, #T_51a96_row2_col2, #T_51a96_row3_col3, #T_51a96_row4_col4, #T_51a96_row5_col5, #T_51a96_row6_col6, #T_51a96_row7_col7, #T_51a96_row8_col8, #T_51a96_row9_col9, #T_51a96_row10_col10, #T_51a96_row11_col11, #T_51a96_row12_col12, #T_51a96_row13_col13, #T_51a96_row14_col14, #T_51a96_row15_col15, #T_51a96_row16_col16 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_51a96_row0_col1, #T_51a96_row1_col9, #T_51a96_row2_col0, #T_51a96_row4_col3, #T_51a96_row4_col15, #T_51a96_row12_col13, #T_51a96_row13_col10 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_51a96_row0_col2, #T_51a96_row15_col2, #T_51a96_row16_col8 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_51a96_row0_col3, #T_51a96_row0_col4, #T_51a96_row1_col2, #T_51a96_row1_col4, #T_51a96_row8_col7, #T_51a96_row11_col12, #T_51a96_row16_col15 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_51a96_row0_col5, #T_51a96_row8_col11, #T_51a96_row9_col0 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_51a96_row0_col6, #T_51a96_row5_col1 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_51a96_row0_col7, #T_51a96_row3_col14 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_51a96_row0_col8 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_51a96_row0_col9, #T_51a96_row11_col3 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_51a96_row0_col10 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_51a96_row0_col11, #T_51a96_row7_col12 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_51a96_row0_col12 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_51a96_row0_col13, #T_51a96_row13_col8 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_51a96_row0_col14 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_51a96_row0_col15, #T_51a96_row1_col13, #T_51a96_row6_col5, #T_51a96_row6_col9, #T_51a96_row6_col10, #T_51a96_row9_col2, #T_51a96_row9_col3, #T_51a96_row9_col4, #T_51a96_row9_col6, #T_51a96_row9_col7, #T_51a96_row9_col8, #T_51a96_row9_col11, #T_51a96_row9_col16, #T_51a96_row15_col0, #T_51a96_row15_col1, #T_51a96_row15_col12, #T_51a96_row15_col14 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_51a96_row0_col16, #T_51a96_row3_col1, #T_51a96_row6_col0, #T_51a96_row8_col16 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_51a96_row1_col0, #T_51a96_row13_col0 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_51a96_row1_col3, #T_51a96_row3_col9, #T_51a96_row3_col16, #T_51a96_row6_col16, #T_51a96_row12_col1, #T_51a96_row16_col7, #T_51a96_row16_col14 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_51a96_row1_col5, #T_51a96_row11_col1, #T_51a96_row14_col10, #T_51a96_row15_col11 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_51a96_row1_col6 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_51a96_row1_col7, #T_51a96_row1_col11, #T_51a96_row12_col15, #T_51a96_row16_col6 {
#   background-color: #bde5b6;
#   color: #000000;
# }
# #T_51a96_row1_col8 {
#   background-color: #aadda4;
#   color: #000000;
# }
# #T_51a96_row1_col10 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_51a96_row1_col12, #T_51a96_row6_col13, #T_51a96_row15_col9, #T_51a96_row16_col13 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_51a96_row1_col14, #T_51a96_row1_col16, #T_51a96_row11_col16, #T_51a96_row16_col11 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_51a96_row1_col15, #T_51a96_row14_col16 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_51a96_row2_col1, #T_51a96_row9_col14 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_51a96_row2_col3, #T_51a96_row3_col2 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_51a96_row2_col4, #T_51a96_row5_col9, #T_51a96_row10_col5 {
#   background-color: #2b934b;
#   color: #f1f1f1;
# }
# #T_51a96_row2_col5, #T_51a96_row4_col9, #T_51a96_row11_col9, #T_51a96_row14_col15, #T_51a96_row16_col3, #T_51a96_row16_col9, #T_51a96_row16_col10 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_51a96_row2_col6, #T_51a96_row3_col13 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_51a96_row2_col7, #T_51a96_row13_col5 {
#   background-color: #60ba6c;
#   color: #f1f1f1;
# }
# #T_51a96_row2_col8, #T_51a96_row6_col2 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_51a96_row2_col9 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_51a96_row2_col10, #T_51a96_row7_col10, #T_51a96_row10_col15 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_51a96_row2_col11, #T_51a96_row11_col2 {
#   background-color: #29914a;
#   color: #f1f1f1;
# }
# #T_51a96_row2_col12, #T_51a96_row13_col7 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_51a96_row2_col13 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_51a96_row2_col14, #T_51a96_row10_col13, #T_51a96_row11_col14 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_51a96_row2_col15, #T_51a96_row13_col9 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_51a96_row2_col16, #T_51a96_row4_col16, #T_51a96_row8_col0, #T_51a96_row8_col3, #T_51a96_row16_col4 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_51a96_row3_col0, #T_51a96_row11_col15, #T_51a96_row12_col7 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_51a96_row3_col4 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_51a96_row3_col5, #T_51a96_row7_col9, #T_51a96_row8_col14 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_51a96_row3_col6 {
#   background-color: #8ace88;
#   color: #000000;
# }
# #T_51a96_row3_col7, #T_51a96_row4_col6 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_51a96_row3_col8, #T_51a96_row14_col9 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_51a96_row3_col10 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_51a96_row3_col11, #T_51a96_row13_col3 {
#   background-color: #4bb062;
#   color: #f1f1f1;
# }
# #T_51a96_row3_col12, #T_51a96_row15_col4 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_51a96_row3_col15, #T_51a96_row4_col13, #T_51a96_row12_col4 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_51a96_row4_col0, #T_51a96_row12_col9 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_51a96_row4_col1, #T_51a96_row14_col11 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_51a96_row4_col2, #T_51a96_row5_col10 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_51a96_row4_col5, #T_51a96_row14_col3, #T_51a96_row16_col5 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_51a96_row4_col7, #T_51a96_row6_col1, #T_51a96_row12_col10 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_51a96_row4_col8 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_51a96_row4_col10, #T_51a96_row7_col5 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_51a96_row4_col11, #T_51a96_row11_col4, #T_51a96_row11_col6 {
#   background-color: #369f54;
#   color: #f1f1f1;
# }
# #T_51a96_row4_col12, #T_51a96_row13_col16 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_51a96_row4_col14, #T_51a96_row14_col6 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_51a96_row5_col0, #T_51a96_row6_col11, #T_51a96_row7_col6 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_51a96_row5_col2, #T_51a96_row5_col4 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_51a96_row5_col3, #T_51a96_row5_col11, #T_51a96_row10_col2, #T_51a96_row15_col13 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_51a96_row5_col6, #T_51a96_row14_col7, #T_51a96_row14_col12 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_51a96_row5_col7, #T_51a96_row8_col13 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_51a96_row5_col8, #T_51a96_row6_col12 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_51a96_row5_col12, #T_51a96_row9_col1 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_51a96_row5_col13 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_51a96_row5_col14, #T_51a96_row15_col7 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_51a96_row5_col15, #T_51a96_row6_col14, #T_51a96_row9_col13 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_51a96_row5_col16, #T_51a96_row10_col11 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_51a96_row6_col3, #T_51a96_row7_col

# %%
x = df.iloc[:,0:-1]
y = df.iloc[:,-1]


scaler = preprocessing.StandardScaler()
scaler.fit(x)
X_scaled_array = scaler.transform(x)
X_scaled_df = pd.DataFrame(X_scaled_array, columns = x.columns)

# %%
#Normalization is the process of scaling individual samples to have unit norm. 
#This process can be useful if you plan to use a quadratic form such as the dot-product or any other kernel.
#To quantify the similarity of any pair of samples.
X_normalized = preprocessing.normalize(X_scaled_df)
# Converting the numpy array into a pandas DataFrame
X_normalized = pd.DataFrame(X_normalized)

# %%
pca2 = PCA(n_components=2)
principalComponents = pca2.fit_transform(X_normalized)

principalDf = pd.DataFrame(data = principalComponents, columns = ['P1', 'P2'])

finalDf = pd.concat([principalDf, df[['TENURE']]], axis = 1)
finalDf.head()
# Out:
#          P1        P2  TENURE
# 0 -0.488186 -0.677233      12
# 1 -0.517294  0.556074      12
# 2  0.334384  0.287313      12
# 3 -0.486617 -0.080780      12
# 4 -0.562175 -0.474770      12

# %%
plt.figure(figsize=(7,7))
plt.scatter(finalDf['P1'],finalDf['P2'],c=finalDf['TENURE'],cmap='prism', s =5)
plt.xlabel('pc1')
plt.ylabel('pc2')
# Out:
# Text(0, 0.5, 'pc2')

# %%
ac2 = AgglomerativeClustering(n_clusters = 2)
 
# Visualizing the clustering
plt.figure(figsize =(6, 6))
plt.scatter(principalDf['P1'], principalDf['P2'],
           c = ac2.fit_predict(principalDf), cmap ='rainbow')
plt.show()

# %%
ac3 = AgglomerativeClustering(n_clusters = 3)
 
# Visualizing the clustering
plt.figure(figsize =(6, 6))
plt.scatter(principalDf['P1'], principalDf['P2'],
           c = ac3.fit_predict(principalDf), cmap ='rainbow')
plt.show()

# %%
ac4 = AgglomerativeClustering(n_clusters = 4)
 
# Visualizing the clustering
plt.figure(figsize =(6, 6))
plt.scatter(principalDf['P1'], principalDf['P2'],
           c = ac4.fit_predict(principalDf), cmap ='rainbow')
plt.show()

# %%
ac5 = AgglomerativeClustering(n_clusters = 5)
 
# Visualizing the clustering
plt.figure(figsize =(6, 6))
plt.scatter(principalDf['P1'], principalDf['P2'],
           c = ac5.fit_predict(principalDf), cmap ='rainbow')
plt.show()

# %%
k = [2, 3, 4, 5]
 
# Appending the silhouette scores of the different models to the list
silhouette_scores = []
silhouette_scores.append(
        silhouette_score(principalDf, ac2.fit_predict(principalDf)))
silhouette_scores.append(
        silhouette_score(principalDf, ac3.fit_predict(principalDf)))
silhouette_scores.append(
        silhouette_score(principalDf, ac4.fit_predict(principalDf)))
silhouette_scores.append(
        silhouette_score(principalDf, ac5.fit_predict(principalDf)))

 
# Plotting a bar graph to compare the results
plt.bar(k, silhouette_scores)
plt.xlabel('Number of clusters', fontsize = 20)
plt.ylabel('S(i)', fontsize = 20)
plt.show()
